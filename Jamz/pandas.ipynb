# %% [markdown]
# # 10 Minutes to pandas
# ## Please learn pandas from these links.
# https://pandas.pydata.org/pandas-docs/stable/10min.html
#
# http://manishamde.github.io/blog/2013/03/07/pandas-and-python-top-10/#numpy
#
# ### You should be able to understand these commands:
# 1. Create and read data: Series and Data Frame, read_csv
# 2. View data: head, tail, index, values, describe
# 3. Select data: slicing, loc, iloc
# 4. Missing data: dropna, fillna, isna
# 5. apply and lambda
# 6. concat, append, reshape
# 6. SQL style function: merge, join, group by

# %% [markdown]
# # Question: please implement the code from these three pages.
# ## Page 1:
# http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/
# ## Page 2:
# http://www.gregreda.com/2013/10/26/working-with-pandas-dataframes/
# ## Page 3:
# http://www.gregreda.com/2013/10/26/using-pandas-on-the-movielens-dataset/
#
# # Make sure you understand all these commands and try to use them in your project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
s = pd.Series([7, 'Heisen', 3.14, -1789710578, 'Happy Eating'])

# %%
s
# Out:
# 0               7
# 1          Heisen
# 2            3.14
# 3     -1789710578
# 4    Happy Eating
# dtype: object

# %%
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}
cities = pd.Series(d)
citiescities['Chicago']
# Out:
# Austin            450.0
# Boston              NaN
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# dtype: float64

# %%
cities['Chicago']cities[cities < 1000]
# Out:
# 1000.0

# %%
cities[cities < 1000]
# Out:
# Austin      450.0
# Portland    900.0
# dtype: float64

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12

# %%
df=pd.read_csv('./the-movies-dataset/movies.csv')
df.head(n = 20)
# Out:
#         budget                                  company    country  \
# 0    8000000.0            Columbia Pictures Corporation        USA
# 1    6000000.0                       Paramount Pictures        USA
# 2   15000000.0                       Paramount Pictures        USA
# 3   18500000.0   Twentieth Century Fox Film Corporation        USA
# 4    9000000.0                     Walt Disney Pictures        USA
# 5    6000000.0                                  Hemdale         UK
# 6   25000000.0                   Henson Associates (HA)         UK
# 7    6000000.0  De Laurentiis Entertainment Group (DEG)        USA
# 8    9000000.0                       Paramount Pictures        USA
# 9   15000000.0                     SLM Production Group        USA
# 10   8800000.0                            Rimfire Films  Australia
# 11  16000000.0           Thorn EMI Screen Entertainment         UK
# 12   6000000.0   Twentieth Century Fox Film Corporation        USA
# ...

# %%
df.describe()
# Out:
#              budget         gross     runtime        score         votes  \
# count  6.820000e+03  6.820000e+03  6820.00000  6820.000000  6.820000e+03
# mean   2.458113e+07  3.349783e+07   106.55132     6.374897  7.121952e+04
# std    3.702254e+07  5.819760e+07    18.02818     1.003142  1.305176e+05
# min    0.000000e+00  7.000000e+01    50.00000     1.500000  2.700000e+01
# 25%    0.000000e+00  1.515839e+06    95.00000     5.800000  7.665250e+03
# 50%    1.100000e+07  1.213568e+07   102.00000     6.400000  2.589250e+04
# 75%    3.200000e+07  4.006534e+07   115.00000     7.100000  7.581225e+04
# max    3.000000e+08  9.366622e+08   366.00000     9.300000  1.861666e+06
#
#               year
# count  6820.000000
# mean   2001.000293
# std       8.944501
# min    1986.000000
# 25%    1993.000000
# 50%    2001.000000
# 75%    2009.000000
# max    2016.000000

# %%
df.tail()
# Out:
#          budget                    company country         director  \
# 6815        0.0   Fox Searchlight Pictures      UK  Mandie Fletcher
# 6816        0.0   Siempre Viva Productions     USA   Paul Duddridge
# 6817  3500000.0     Warner Bros. Animation     USA          Sam Liu
# 6818        0.0        Borderline Presents     USA    Nicolas Pesce
# 6819        0.0  Les Productions du Tr�sor  France    Nicole Garcia
#
#           genre      gross                            name rating    released  \
# 6815     Comedy  4750497.0  Absolutely Fabulous: The Movie      R  2016-07-22
# 6816      Drama    28368.0           Mothers and Daughters  PG-13  2016-05-06
# 6817  Animation  3775000.0        Batman: The Killing Joke      R  2016-07-25
# 6818      Drama    25981.0           The Eyes of My Mother      R  2016-12-02
# 6819      Drama    37757.0       From the Land of the Moon      R  2017-07-28
#
#       runtime  score               star  votes             writer  year
# ...

# %%
df[10:11]
# Out:
#        budget        company    country      director      genre        gross  \
# 10  8800000.0  Rimfire Films  Australia  Peter Faiman  Adventure  174635000.0
#
#                 name rating    released  runtime  score        star  votes  \
# 10  Crocodile Dundee  PG-13  1986-09-26       97    6.5  Paul Hogan  79465
#
#         writer  year
# 10  Ken Shadie  1986

# %%
df['company'].head()
# Out:
# 0             Columbia Pictures Corporation
# 1                        Paramount Pictures
# 2                        Paramount Pictures
# 3    Twentieth Century Fox Film Corporation
# 4                      Walt Disney Pictures
# Name: company, dtype: object

# %%
print(df[['name', 'country']].head(n=20))
print('\n')
# Out:
#                            name    country
# 0                   Stand by Me        USA
# 1      Ferris Bueller's Day Off        USA
# 2                       Top Gun        USA
# 3                        Aliens        USA
# 4       Flight of the Navigator        USA
# 5                       Platoon         UK
# 6                     Labyrinth         UK
# 7                   Blue Velvet        USA
# 8                Pretty in Pink        USA
# 9                       The Fly        USA
# 10             Crocodile Dundee  Australia
# 11                   Highlander         UK
# 12                        Lucas        USA
# 13  Big Trouble in Little China        USA
# 14                    Manhunter        USA
# 15                     9� Weeks        USA
# 16            Maximum Overdrive        USA
# 17       Little Shop of Horrors        USA
# 18                   The Wraith        USA
# 19              Howard the Duck        USA

# %%
print(df.iloc[20])
# Out:
# budget                2e+06
# company     New Line Cinema
# country                 USA
# director      Stephen Herek
# genre                Action
# gross           1.31672e+07
# name               Critters
# rating                PG-13
# released         1986-04-11
# runtime                  82
# score                     6
# star            Dee Wallace
# votes                 25517
# writer         Domonic Muir
# year                   1986
# Name: 20, dtype: object

# %%
print(df.loc[90])
# Out:
# budget                             0
# company     Kings Road Entertainment
# country                          USA
# director                 Jim McBride
# genre                         Comedy
# gross                    1.76853e+07
# name                    The Big Easy
# rating                             R
# released                  1987-08-28
# runtime                          102
# score                            6.6
# star                    Dennis Quaid
# votes                          10022
# writer             Daniel Petrie Jr.
# year                            1986
# Name: 90, dtype: object

# %%
df.dropna()
# Out:
#           budget                                  company    country  \
# 0      8000000.0            Columbia Pictures Corporation        USA
# 1      6000000.0                       Paramount Pictures        USA
# 2     15000000.0                       Paramount Pictures        USA
# 3     18500000.0   Twentieth Century Fox Film Corporation        USA
# 4      9000000.0                     Walt Disney Pictures        USA
# 5      6000000.0                                  Hemdale         UK
# 6     25000000.0                   Henson Associates (HA)         UK
# 7      6000000.0  De Laurentiis Entertainment Group (DEG)        USA
# 8      9000000.0                       Paramount Pictures        USA
# 9     15000000.0                     SLM Production Group        USA
# 10     8800000.0                            Rimfire Films  Australia
# 11    16000000.0           Thorn EMI Screen Entertainment         UK
# 12     6000000.0   Twentieth Century Fox Film Corporation        USA
# ...

# %%
df.fillna(value = 1)
# Out:
#           budget                                  company    country  \
# 0      8000000.0            Columbia Pictures Corporation        USA
# 1      6000000.0                       Paramount Pictures        USA
# 2     15000000.0                       Paramount Pictures        USA
# 3     18500000.0   Twentieth Century Fox Film Corporation        USA
# 4      9000000.0                     Walt Disney Pictures        USA
# 5      6000000.0                                  Hemdale         UK
# 6     25000000.0                   Henson Associates (HA)         UK
# 7      6000000.0  De Laurentiis Entertainment Group (DEG)        USA
# 8      9000000.0                       Paramount Pictures        USA
# 9     15000000.0                     SLM Production Group        USA
# 10     8800000.0                            Rimfire Films  Australia
# 11    16000000.0           Thorn EMI Screen Entertainment         UK
# 12     6000000.0   Twentieth Century Fox Film Corporation        USA
# ...

# %%
df.apply(np.cumsum)
# Out:
#             budget                                            company  \
# 0     8.000000e+06                      Columbia Pictures Corporation
# 1     1.400000e+07    Columbia Pictures CorporationParamount Pictures
# 2     2.900000e+07  Columbia Pictures CorporationParamount Picture...
# 3     4.750000e+07  Columbia Pictures CorporationParamount Picture...
# 4     5.650000e+07  Columbia Pictures CorporationParamount Picture...
# 5     6.250000e+07  Columbia Pictures CorporationParamount Picture...
# 6     8.750000e+07  Columbia Pictures CorporationParamount Picture...
# 7     9.350000e+07  Columbia Pictures CorporationParamount Picture...
# 8     1.025000e+08  Columbia Pictures CorporationParamount Picture...
# 9     1.175000e+08  Columbia Pictures CorporationParamount Picture...
# 10    1.263000e+08  Columbia Pictures CorporationParamount Picture...
# 11    1.423000e+08  Columbia Pictures CorporationParamount Picture...
# ...

# %%
df = pd.DataFrame(np.random.randn(12, 4), columns=['director','genre','name','score'])
df
# Out:
#     director     genre      name     score
# 0   1.883438  0.550958  0.032801 -0.237768
# 1   0.232055  0.715359 -0.994570  0.735261
# 2   0.134050  1.410361 -1.330724  0.762832
# 3  -1.446124  0.549903  0.314987 -0.567227
# 4   0.268461 -1.775078 -0.061787  0.698751
# 5  -0.811257 -0.779039  0.554011  0.663235
# 6   0.075530 -0.072687 -2.037430  0.127569
# 7   1.387545 -0.078027  0.448093 -0.604397
# 8   0.058904  0.092763 -0.504862  1.071171
# 9   1.492645 -2.997608 -0.148417 -0.038853
# 10 -0.124614  0.513956  1.653192  1.791830
# 11  0.817106  0.097471  0.257928  2.186104

# %%
name = [df[:7], df[7:10], df[7:]]
name
# Out:
# [   director     genre      name     score
#  0  1.883438  0.550958  0.032801 -0.237768
#  1  0.232055  0.715359 -0.994570  0.735261
#  2  0.134050  1.410361 -1.330724  0.762832
#  3 -1.446124  0.549903  0.314987 -0.567227
#  4  0.268461 -1.775078 -0.061787  0.698751
#  5 -0.811257 -0.779039  0.554011  0.663235
#  6  0.075530 -0.072687 -2.037430  0.127569,
#     director     genre      name     score
#  7  1.387545 -0.078027  0.448093 -0.604397
#  8  0.058904  0.092763 -0.504862  1.071171
#  9  1.492645 -2.997608 -0.148417 -0.038853,
#      director     genre      name     score
#  7   1.387545 -0.078027  0.448093 -0.604397
#  8   0.058904  0.092763 -0.504862  1.071171
#  9   1.492645 -2.997608 -0.148417 -0.038853
#  10 -0.124614  0.513956  1.653192  1.791830
#  11  0.817106  0.097471  0.257928  2.186104]

# %%
pd.concat(name)
# Out:
#     director     genre      name     score
# 0   1.883438  0.550958  0.032801 -0.237768
# 1   0.232055  0.715359 -0.994570  0.735261
# 2   0.134050  1.410361 -1.330724  0.762832
# 3  -1.446124  0.549903  0.314987 -0.567227
# 4   0.268461 -1.775078 -0.061787  0.698751
# 5  -0.811257 -0.779039  0.554011  0.663235
# 6   0.075530 -0.072687 -2.037430  0.127569
# 7   1.387545 -0.078027  0.448093 -0.604397
# 8   0.058904  0.092763 -0.504862  1.071171
# 9   1.492645 -2.997608 -0.148417 -0.038853
# 7   1.387545 -0.078027  0.448093 -0.604397
# 8   0.058904  0.092763 -0.504862  1.071171
# 9   1.492645 -2.997608 -0.148417 -0.038853
# 10 -0.124614  0.513956  1.653192  1.791830
# 11  0.817106  0.097471  0.257928  2.186104
